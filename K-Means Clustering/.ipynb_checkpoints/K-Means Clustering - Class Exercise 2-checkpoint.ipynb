# %% [markdown]
# # K-Means Clustering - Class Exercise 2

# %% [markdown]
# ## Introduction
#
# The wine dataset captures the intricate characteristics of wine, a dataset not only rich with chemical composition but also flavored with the art of winemaking. This dataset comprises numerous physicochemical attributes, including fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, and alcohol content, each playing a critical role in the complex profile of wine.
#
# We wish to apply clustering algorithms to discern inherent groupings within the data. Such an analysis can offer insights into the relationships and patterns that define wine qualities, potentially guiding sommeliers and enthusiasts alike in understanding the subtleties that distinguish one type of wine from another.
#
# Perform K-means clustering on the wine dataset and determine the optimal number of clusters to use.

# %% [markdown]
# ## Metadata
#
# | Variables           | Description                                             |
# |---------------------|---------------------------------------------------------|
# | fixed acidity       | Acidity of wine related to the tartness or sharp taste  |
# | volatile acidity    | Amount of acetic acid in wine, too much leads to an unpleasant vinegar taste |
# | citric acid         | Found in small quantities, citric acid can add 'freshness' and flavor to wines |
# | residual sugar      | Amount of sugar remaining after fermentation stops, it's usually less in dry wines |
# | chlorides           | Amount of salt in the wine                              |
# | free sulfur dioxide | Free form of SO2, it prevents microbial growth and the oxidation of wine |
# | total sulfur dioxide| Amount of free and bound forms of SO2, used as a preservative due to its antioxidant and antibacterial properties |
# | density             | Density of the wine which is affected by its alcohol and sugar content |
# | pH                  | Describes the acidity or basicity of the wine on a scale of 0 (very acidic) to 14 (very basic) |
# | sulphates           | Wine additive which can contribute to sulfur dioxide gas (SO2) levels, acts as an antimicrobial and antioxidant |
# | alcohol             | The percentage of alcohol content in the wine           |
# | Type                | The category or type of wine, such as red or white      |

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from pandas.plotting import parallel_coordinates

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv('_.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.1              0.46         0.31             1.7      0.052
# 1               5.2              0.28         0.29             1.1      0.028
# 2               6.2              0.19         0.38             5.1      0.019
# 3              10.6              0.83         0.37             2.6      0.086
# 4               6.8              0.46         0.26             2.7      0.042
# ...             ...               ...          ...             ...        ...
# 6492            8.1              0.45         0.34             8.3      0.037
# 6493            8.9              0.50         0.21             2.2      0.088
# 6494            6.9              0.28         0.27             2.1      0.036
# 6495            7.1              0.20         0.34            16.0      0.050
# 6496            7.4              0.24         0.22            10.7      0.042
#
# ...

# %% [markdown]
# ## Drop target vatiable
#
# Since clustering is an unsupervised learning technique, we do not need the target variable ```Type``` in our analysis and will therefore drop this variable from the dataset.

# %%
df = df.drop(_, axis=1)
df.shape
# Out:
# (6497, 11)

# %% [markdown]
# ## Check for missing values

# %%
missing_values = df._
missing_values
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# dtype: int64

# %% [markdown]
# We observe that there are no missing values in the dataset.

# %% [markdown]
# ## Normalize data
#
# Clustering uses distance metrics to measure similarity between objects, and these distance metrics are sensitive to the scale of data. Hence, we will normalize the data to ensure that variables with larger numerical values do not dominate the distance calculations.

# %%
# Create instance of min-max normalizer
normalizer = MinMaxScaler()

# Fit normalizer to the data
_

# Normalize the data
_

# %% [markdown]
# ## Fit K-Means model

# %%
# Specify model parameters
K = 3
random_seed = 9002

# Build model
model = KMeans(_)

# Fit model on dataset
_

# Convert dataset to dataframe
df_norm = pd.DataFrame(_, columns=_)

# Append final cluster labels to original dataset
cluster_labels = _
df_norm['Cluster'] = cluster_labels

# Display appended dataset
df_norm
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.355372          0.253333     0.186747        0.016871   0.071429
# 1          0.115702          0.133333     0.174699        0.007669   0.031561
# 2          0.198347          0.073333     0.228916        0.069018   0.016611
# 3          0.561983          0.500000     0.222892        0.030675   0.127907
# 4          0.247934          0.253333     0.156627        0.032209   0.054817
# ...             ...               ...          ...             ...        ...
# 6492       0.355372          0.246667     0.204819        0.118098   0.046512
# 6493       0.421488          0.280000     0.126506        0.024540   0.131229
# 6494       0.256198          0.133333     0.162651        0.023006   0.044850
# 6495       0.272727          0.080000     0.204819        0.236196   0.068106
# 6496       0.297521          0.106667     0.132530        0.154908   0.054817
#
# ...

# %% [markdown]
# ## Display Cluster Sizes and Cluster Centroids

# %%
# Display cluster sizes
cluster_counts = df_norm._
cluster_counts
# Out:
# Cluster
# 0    2682
# 1    2314
# 2    1501
# dtype: int64

# %%
# Display cluster centroids
cluster_centroids = df_norm._
cluster_centroids
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# Cluster
# 0             0.260041          0.130859     0.205751        0.121575
# 1             0.246600          0.134427     0.197887        0.047869
# 2             0.376922          0.308243     0.158128        0.030501
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# Cluster
# 0         0.072554             0.135582              0.350518  0.171023
# 1         0.050533             0.098042              0.242658  0.089874
# 2         0.130635             0.050340              0.094125  0.188951
#
#                pH  sulphates   alcohol
# Cluster
# 0        0.348479   0.154310  0.230095
# 1        0.386327   0.155393  0.538240
# 2        0.454421   0.241633  0.322228

# %% [markdown]
# ## Visualize Clustering Results

# %%
# Parallel coordinates plot
plt.figure(figsize=(12, 6))
parallel_coordinates(df_norm, class_column='Cluster', color=plt.cm.jet(np.linspace(0, 1, model.n_clusters)))
plt.show()

# %% [markdown]
# From the parallel coordinates plot, we observe that ```total sulfur dioxide``` and ```alcohol``` offer a good separation between the three clusters. Hence, we will use these two variables to visualize the clustering results on a scatter plot next.

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
clusters = df_norm['Cluster'].unique()
for cluster in clusters:
    cluster_data = _
    plt.scatter(_, _, label=f'Cluster {cluster}')
plt.xlabel('Total Sulfur Dioxide')
plt.ylabel('Alcohol')
plt.legend()
plt.show()

# %% [markdown]
# ## Elbow Method
#
# We will now implement the elbow method to find the optimal number of clusters ```K```.

# %%
# Write a custom function to implement the elbow method

def elbow(data, max_clusters):
    """
    Performs the elbow method on the given dataset to find the optimal number of clusters by plotting the Within-Cluster Sum of Squares (WCSS).

    Parameters:
    - data: The dataset to cluster, as a NumPy array or pandas DataFrame.
    - max_clusters: The maximum number of clusters to try.
    """
    
    wcss = []
    for i in range(_):
        kmeans = KMeans(_, random_state=9002)
        _
        wcss.append(_)
    
    plt.figure(figsize=(10, 6))
    plt.plot(_, _, marker='o', linestyle='-', markersize=8)
    plt.title('Elbow Plot')
    plt.xlabel('Number of clusters')
    plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
    plt.xticks(range(1, max_clusters + 1))
    plt.show()

# %%
# Generate the elbow plot
elbow(data_norm, max_clusters=10)
